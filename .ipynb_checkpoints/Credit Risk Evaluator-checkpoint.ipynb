# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
train_df = pd.read_csv(Path('Resources/Generator/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/Generator/2020Q1loans.csv'))

# %%
# Convert categorical data to numeric and separate target feature for training data


train_binary_encoded = pd.get_dummies(train_df, columns=['home_ownership', 'verification_status',
                                                         'pymnt_plan', 'initial_list_status',
                                                         'application_type','hardship_flag',
                                                         'debt_settlement_flag'])
label_encoder = LabelEncoder()

label_encoder.fit(train_binary_encoded['loan_status'])

train_binary_encoded['loan_status_le'] = label_encoder.transform(train_binary_encoded['loan_status'])

loan_status_num = {
    "low_risk": 0,
    "high_risk": 1
}

train_binary_encoded['loan_status_num'] = train_df['loan_status'].apply(lambda x: loan_status_num[x])
train_binary_encoded.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loan_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/5k/k2z13ft93tl12wvdks82c4pc0000gn/T/ipykernel_26974/1320909885.py in <module>
#       8 label_encoder = LabelEncoder()
#       9
# ---> 10 label_encoder.fit(train_binary_encoded['loan_status'])
#      11
#      12 train_binary_encoded['loan_status_le'] = label_encoder.transform(train_binary_encoded['loan_status'])
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'loan_status'

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_binary_encoded = pd.get_dummies(test_df, columns=['home_ownership', 'verification_status',
                                                         'pymnt_plan', 'initial_list_status',
                                                         'application_type','hardship_flag',
                                                         'debt_settlement_flag'])
#label_encoder = LabelEncoder()

#label_encoder.fit(test_binary_encoded['loan_status'])

#test_binary_encoded['loan_status_le'] = label_encoder.transform(test_binary_encoded['loan_status'])

loan_status_num = {
    "low_risk": 0,
    "high_risk": 1
}

test_binary_encoded['loan_status_num'] = test_df['loan_status'].apply(lambda x: loan_status_num[x])
test_binary_encoded.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc  \
# 0       67991  67991    40000.0    0.0819       814.70    140000.0
# 1       25429  25429     6000.0    0.1524       208.70     55000.0
# 2       38496  38496     3600.0    0.1695       128.27     42000.0
# 3       19667  19667    20000.0    0.1524       478.33    100000.0
# 4       37505  37505     3600.0    0.1240       120.27     50000.0
#
#   loan_status    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0    low_risk  19.75          0.0             1.0  ...
# 1    low_risk  11.52          2.0             0.0  ...
# 2    low_risk   6.74          0.0             0.0  ...
# 3    low_risk  12.13          0.0             2.0  ...
# 4    low_risk  16.08          0.0             3.0  ...
#
#    verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                             0             1                      0
# 1                             0             1                      0
# 2                             0             1                      0
# 3                             0             1                      0
# 4                             0             1                      0
#
#    initial_list_status_w  application_type_Individual  \
# 0                      1                            1
# 1                      1                            1
# 2                      1                            1
# 3                      1                            1
# 4                      1                            1
#
#    application_type_Joint App  hardship_flag_N  hardship_flag_Y  \
# 0                           0                1                0
# 1                           0                1                0
# 2                           0                1                0
# 3                           0                1                0
# 4                           0                1                0
#
#    debt_settlement_flag_N  loan_status_num
# 0                       1                0
# 1                       1                0
# 2                       1                0
# 3                       1                0
# 4                       1                0
#
# [5 rows x 95 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5k/k2z13ft93tl12wvdks82c4pc0000gn/T/ipykernel_22046/2861454670.py in <module>
# ----> 1 test_binary_encoded.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
